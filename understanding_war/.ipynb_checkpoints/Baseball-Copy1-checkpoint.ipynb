# %% [markdown]
# # <font color='blue'>Part 1: Setting Up </font>

# %% [markdown]
# First, let's make sure this notebook works well in both python 2 and 3, import a few common modules, ensure MatplotLib plots figures inline and prepare a function to save the figures:

# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os


# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # <font color='blue'>Part 2: Creating Train and Test Sets </font>

# %% [markdown]
# ### 2.1: Creating Data-Fetching Function

# %%
import os
import tarfile
from six.moves import urllib
import pandas as pd

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/rnz269/ml_baseball/master/understanding_war/excel_files/"
DATA_FILE_PATH = os.path.join("datasets", "baseball")

# Following function automates the data fetching process
def fetch_dataset(data_file_name, data_file_path=DATA_FILE_PATH):
   # Defines network location of data file
    data_absolute_url = DOWNLOAD_ROOT + data_file_name
   # Creates a local path to contain the to-be-pulled network data file
    if not os.path.isdir(data_file_path):
        os.makedirs(data_file_path)
    data_csv_path = os.path.join(data_file_path, data_file_name)
    # Retrieves data file from network location and stores in the local path we created
    urllib.request.urlretrieve(data_absolute_url, data_csv_path)
    return pd.read_csv(data_csv_path)

# %% [markdown]
# ### Change the next cell if you want to access different data:

# %%
# This won't work if the file is open, as excel won't allow you to rewrite an open file
dataset = fetch_dataset("mlb_4_year_samples.csv")
dataset.head()
# Out:
#    y1 Age  y1 G  y1 PA  y1 HR  y1 R  y1 RBI  y1 SB  y1 BB%  y1 K%  y1 ISO  \
# 0      23    81    313      8    37      27      9   0.077  0.268   0.146
# 1      28   123    559      7    82      34     12   0.104  0.204   0.126
# 2      25    45    112      1    13      10      0   0.071  0.125   0.109
# 3      25    53    138      1    15      12      0   0.058  0.101   0.089
# 4      27    47    123      0     9      10      1   0.057  0.195   0.028
#
#     ...    y4 BABIP  y4 AVG  y4 OBP  y4 SLG  y4 WOBA  y4 wRC+  y4 BsR  y4 Off  \
# 0   ...       0.248   0.217   0.281   0.336    0.270       64    -0.3   -15.9
# 1   ...       0.208   0.173   0.285   0.250    0.254       54    -2.2   -14.8
# 2   ...       0.244   0.215   0.256   0.283    0.236       50    -0.8   -16.2
# 3   ...       0.301   0.253   0.316   0.405    0.313       93    -1.5    -3.4
# 4   ...       0.291   0.236   0.304   0.322    0.279       70     1.8    -5.3
#
#    y4 Def  y4 WAR
# 0     1.5    -0.2
# 1   -11.0    -1.9
# 2     2.9    -0.5
# 3    -2.3     0.1
# 4     4.4     0.6
#
# [5 rows x 80 columns]

# %%
# This is our test set
test_dataset = fetch_dataset("mlb_4_year_test.csv")
test_dataset.head()
# Out:
#    y1 Age  y1 G  y1 PA  y1 HR  y1 R  y1 RBI  y1 SB  y1 BB%  y1 K%  y1 ISO  \
# 0      33    93    347      3    21      25      0   0.153  0.164   0.064
# 1      37   102    362      5    25      37      0   0.039  0.149   0.086
# 2      24    69    225      1    22      18      4   0.160  0.249   0.059
# 3      32   133    541     10    52      60      4   0.052  0.170   0.124
# 4      25    59    220      3    19      15      4   0.055  0.273   0.103
#
#     ...    y3 BABIP  y3 AVG  y3 OBP  y3 SLG  y3 WOBA  y3 wRC+  y3 BsR  y3 Off  \
# 0   ...       0.252   0.216   0.301   0.298    0.266       64    -1.3   -10.0
# 1   ...       0.237   0.219   0.243   0.304    0.236       41    -3.3   -22.2
# 2   ...       0.248   0.217   0.281   0.336    0.270       64    -0.3   -15.9
# 3   ...       0.284   0.262   0.336   0.378    0.313       90     2.3    -2.9
# 4   ...       0.331   0.264   0.294   0.401    0.294       80     1.1    -3.6
#
#    y3 Def  y3 WAR
# 0     2.9    -0.1
# 1     4.6    -1.0
# 2     1.5    -0.2
# 3     0.1     1.1
# 4     0.4     0.3
#
# [5 rows x 60 columns]

# %% [markdown]
# ### 2.2: Checking out Descriptive Stats on Data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1814 entries, 0 to 1813
# Data columns (total 80 columns):
# y1 Age      1814 non-null int64
# y1 G        1814 non-null int64
# y1 PA       1814 non-null int64
# y1 HR       1814 non-null int64
# y1 R        1814 non-null int64
# y1 RBI      1814 non-null int64
# y1 SB       1814 non-null int64
# y1 BB%      1814 non-null float64
# y1 K%       1814 non-null float64
# y1 ISO      1814 non-null float64
# y1 BABIP    1814 non-null float64
# y1 AVG      1814 non-null float64
# y1 OBP      1814 non-null float64
# y1 SLG      1814 non-null float64
# y1 WOBA     1814 non-null float64
# y1 wRC+     1814 non-null int64
# y1 BsR      1814 non-null float64
# y1 Off      1814 non-null float64
# y1 Def      1814 non-null float64
# y1 WAR      1814 non-null float64
# y2 Age      1814 non-null int64
# y2 G        1814 non-null int64
# y2 PA       1814 non-null int64
# y2 HR       1814 non-null int64
# y2 R        1814 non-null int64
# y2 RBI      1814 non-null int64
# y2 SB       1814 non-null int64
# y2 BB%      1814 non-null float64
# y2 K%       1814 non-null float64
# y2 ISO      1814 non-null float64
# y2 BABIP    1814 non-null float64
# y2 AVG      1814 non-null float64
# y2 OBP      1814 non-null float64
# y2 SLG      1814 non-null float64
# y2 WOBA     1814 non-null float64
# y2 wRC+     1814 non-null int64
# y2 BsR      1814 non-null float64
# y2 Off      1814 non-null float64
# y2 Def      1814 non-null float64
# y2 WAR      1814 non-null float64
# y3 Age      1814 non-null int64
# y3 G        1814 non-null int64
# y3 PA       1814 non-null int64
# y3 HR       1814 non-null int64
# y3 R        1814 non-null int64
# y3 RBI      1814 non-null int64
# y3 SB       1814 non-null int64
# y3 BB%      1814 non-null float64
# y3 K%       1814 non-null float64
# y3 ISO      1814 non-null float64
# y3 BABIP    1814 non-null float64
# y3 AVG      1814 non-null float64
# y3 OBP      1814 non-null float64
# y3 SLG      1814 non-null float64
# y3 WOBA     1814 non-null float64
# y3 wRC+     1814 non-null int64
# y3 BsR      1814 non-null float64
# y3 Off      1814 non-null float64
# y3 Def      1814 non-null float64
# y3 WAR      1814 non-null float64
# y4 Age      1814 non-null int64
# y4 G        1814 non-null int64
# y4 PA       1814 non-null int64
# y4 HR       1814 non-null int64
# y4 R        1814 non-null int64
# y4 RBI      1814 non-null int64
# y4 SB       1814 non-null int64
# y4 BB%      1814 non-null float64
# y4 K%       1814 non-null float64
# y4 ISO      1814 non-null float64
# y4 BABIP    1814 non-null float64
# y4 AVG      1814 non-null float64
# y4 OBP      1814 non-null float64
# y4 SLG      1814 non-null float64
# y4 WOBA     1814 non-null float64
# y4 wRC+     1814 non-null int64
# y4 BsR      1814 non-null float64
# y4 Off      1814 non-null float64
# y4 Def      1814 non-null float64
# y4 WAR      1814 non-null float64
# dtypes: float64(48), int64(32)
# memory usage: 1.1 MB

# %%
dataset["y1 HR"].value_counts()
# Out:
# 3     95
# 1     93
# 2     84
# 4     83
# 6     83
# 5     82
# 8     81
# 9     79
# 7     75
# 11    70
# 10    67
# 12    67
# 15    60
# 13    54
# 0     51
# 16    50
# 14    49
# 20    48
# 23    46
# 21    45
# 18    44
# 25    38
# 17    36
# 24    35
# 22    34
# 19    28
# 27    26
# 32    24
# 30    23
# 26    22
# 33    20
# 29    19
# 31    19
# 28    17
# 34    12
# 36    11
# 37     8
# 39     5
# 35     4
# 38     4
# 40     3
# 43     3
# 44     3
# 41     2
# 42     2
# 46     2
# 47     2
# 54     2
# 53     1
# 45     1
# 48     1
# 50     1
# Name: y1 HR, dtype: int64

# %%
# Wait a second! y1 Age could be Harper's first year in bigs or his second year, as I split 4 year samples
# Harper had five years in bigs, 2012-2016, so that's two samples
war_features = ["y1 Age", "y1 WAR", "y2 Age", "y2 WAR", "y3 Age", "y3 WAR", "y4 Age", "y4 WAR"]
dataset[war_features].describe()
# Out:
#             y1 Age       y1 WAR       y2 Age       y2 WAR       y3 Age  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean     27.573870     2.013782    28.610254     2.013561    29.646637
# std       3.591649     1.989672     3.580564     2.002952     3.576020
# min      19.000000    -2.900000    20.000000    -2.900000    21.000000
# 25%      25.000000     0.600000    26.000000     0.500000    27.000000
# 50%      27.000000     1.700000    28.000000     1.700000    29.000000
# 75%      30.000000     3.100000    31.000000     3.200000    32.000000
# max      42.000000    10.500000    43.000000    10.500000    44.000000
#
#             y3 WAR       y4 Age       y4 WAR
# count  1814.000000  1814.000000  1814.000000
# mean      1.862128    30.680265     1.564168
# std       1.985206     3.580032     2.009985
# min      -2.900000    22.000000    -2.900000
# 25%       0.400000    28.000000     0.000000
# 50%       1.500000    30.000000     1.100000
# 75%       3.000000    33.000000     2.700000
# max      10.500000    45.000000     9.500000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
resultant = ["y1 HR", "y1 AVG", "y1 OBP", "y1 SLG", "y1 WOBA", "y1 wRC+", "y1 BsR", "y1 WAR"]
baseball_resultant = dataset[resultant]
baseball_resultant.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ### 2.3: Ensuring Test Data Never Sees Train Data on Update

# %%
# To make this notebook's output identical at every run
np.random.seed(42)

# %%
import numpy as np

# Given dataset, test ratio, returns training set, test set (train_indices, test_indices)
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    # From 1:test_set_size
    test_indices = shuffled_indices[:test_set_size]
    # From test_set_size:n
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(dataset, 0.0)
print(len(train_set), "train +", len(test_set), "test")
# Out:
# 1814 train + 0 test

# %%
import hashlib

# The following function makes sure upon loading this page that the test data is always the same 20%, important for holdout and generalization error calculation
def test_set_check(identifier, test_ratio, hash):
    # Compute hash of each instance's identifier, then look at last byte of hash, and is True if less than 256 * test_ratio
    return hash(np.int64(identifier)).digest()[-1] < 256 * test_ratio

def split_train_test_by_id(data, test_ratio, id_column, hash=hashlib.md5):
    ids = data[id_column]
    # lambda id_ is an anonymous function that returns the true/false value for each in test_set_check(id_, test_ratio, hash)
    # making in_test_set a boolean array
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio, hash))
    # print(~in_test_set)
    # The ~ defines complement, just reverses the true false values to return training set first
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
# Unfortunately, our baseball dataset doesn't have an identifier column, so here:
# the following line adds an index column to our baseball dataset
baseball_with_id = dataset.reset_index()
train_set, test_set = split_train_test_by_id(baseball_with_id, 0, "index")
# make sure new data is always appended to end of housing_with_id to ensure the same data is always withheld from testing

# %% [markdown]
# ### 2.4: Starting to use sklearn

# %%
test_set.head()
# Out:
# Empty DataFrame
# Columns: [index, y1 Age, y1 G, y1 PA, y1 HR, y1 R, y1 RBI, y1 SB, y1 BB%, y1 K%, y1 ISO, y1 BABIP, y1 AVG, y1 OBP, y1 SLG, y1 WOBA, y1 wRC+, y1 BsR, y1 Off, y1 Def, y1 WAR, y2 Age, y2 G, y2 PA, y2 HR, y2 R, y2 RBI, y2 SB, y2 BB%, y2 K%, y2 ISO, y2 BABIP, y2 AVG, y2 OBP, y2 SLG, y2 WOBA, y2 wRC+, y2 BsR, y2 Off, y2 Def, y2 WAR, y3 Age, y3 G, y3 PA, y3 HR, y3 R, y3 RBI, y3 SB, y3 BB%, y3 K%, y3 ISO, y3 BABIP, y3 AVG, y3 OBP, y3 SLG, y3 WOBA, y3 wRC+, y3 BsR, y3 Off, y3 Def, y3 WAR, y4 Age, y4 G, y4 PA, y4 HR, y4 R, y4 RBI, y4 SB, y4 BB%, y4 K%, y4 ISO, y4 BABIP, y4 AVG, y4 OBP, y4 SLG, y4 WOBA, y4 wRC+, y4 BsR, y4 Off, y4 Def, y4 WAR]
# Index: []
#
# [0 rows x 81 columns]

# %%
train_set.describe()
# Out:
#              index       y1 Age         y1 G        y1 PA        y1 HR  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean    906.500000    27.573870   116.104190   454.283352    13.269570
# std     523.801012     3.591649    37.076949   182.305890    10.096915
# min       0.000000    19.000000    22.000000   100.000000     0.000000
# 25%     453.250000    25.000000    88.000000   302.250000     5.000000
# 50%     906.500000    27.000000   125.000000   484.000000    11.000000
# 75%    1359.750000    30.000000   149.000000   614.000000    20.000000
# max    1813.000000    42.000000   163.000000   778.000000    54.000000
#
#               y1 R       y1 RBI        y1 SB       y1 BB%        y1 K%  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean     56.800992    54.047409     8.352260     0.086315     0.179969
# std      28.060540    29.679516    10.623266     0.031443     0.057665
# min       4.000000     2.000000     0.000000     0.006000     0.043000
# 25%      33.000000    30.000000     1.000000     0.064000     0.137250
# 50%      56.000000    51.000000     4.000000     0.083000     0.175000
# 75%      79.000000    76.000000    11.000000     0.106000     0.218000
# max     143.000000   156.000000    78.000000     0.207000     0.380000
#
#           ...          y4 BABIP       y4 AVG       y4 OBP       y4 SLG  \
# count     ...       1814.000000  1814.000000  1814.000000  1814.000000
# mean      ...          0.294716     0.255066     0.322724     0.404682
# std       ...          0.038271     0.035141     0.038983     0.076147
# min       ...          0.146000     0.140000     0.193000     0.183000
# 25%       ...          0.270000     0.233000     0.298000     0.351250
# 50%       ...          0.297000     0.256000     0.323000     0.402000
# 75%       ...          0.320000     0.280000     0.347000     0.454000
# max       ...          0.408000     0.359000     0.474000     0.649000
#
#            y4 WOBA      y4 wRC+       y4 BsR       y4 Off       y4 Def  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean      0.317909    98.560639    -0.274807     2.212073    -1.271499
# std       0.042510    28.566571     3.288815    14.724312     8.735438
# min       0.180000     6.000000   -12.700000   -32.800000   -32.300000
# 25%       0.290000    80.000000    -2.100000    -7.800000    -6.900000
# 50%       0.318500    99.000000    -0.300000    -0.700000    -1.300000
# 75%       0.345000   117.000000     1.400000     9.400000     4.000000
# max       0.461000   197.000000    13.600000    77.300000    28.000000
#
#             y4 WAR
# count  1814.000000
# mean      1.564168
# std       2.009985
# min      -2.900000
# 25%       0.000000
# 50%       1.100000
# 75%       2.700000
# max       9.500000
#
# [8 rows x 81 columns]

# %% [markdown]
# # <font color='blue'>Part 3: Discover and visualize the data to gain insights </font>

# %%
# Creates a copy of baseball training set for us to play with without worry
train_set_copy = train_set.copy()

# %%
# Plotting LD% against WAR for all training examples
train_set_copy.plot(kind="scatter", x="y3 BB%", y="y3 wRC+")

# %%
# Size of circle determined by population, option s
# Color of circle represents median_house_value, c, which is the label
train_set_copy.plot(kind="scatter", x="y3 BB%", y="y3 ISO", figsize=(10,7),
    c="y3 WAR", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()

# %% [markdown]
# From above graph, clearly see that combination of high power and high patience correlates highly with WAR

# %% [markdown]
# ### 3.2: Examining Correlations Among All Features

# %%
# Creates a correlation matrix: a square, n x n matrix for n variables

attributes = ["y3 K%", "y3 BB%", "y3 ISO",  "y3 wRC+", "y1 WAR", "y2 WAR", "y3 WAR", "y4 WAR"]
corr_matrix = train_set_copy[attributes].corr()
print(corr_matrix)
# Out:
#             y3 K%    y3 BB%    y3 ISO   y3 wRC+    y1 WAR    y2 WAR    y3 WAR  \
# y3 K%    1.000000  0.191415  0.302459 -0.044223 -0.115026 -0.128201 -0.150516
# y3 BB%   0.191415  1.000000  0.359493  0.440045  0.224922  0.211320  0.294317
# y3 ISO   0.302459  0.359493  1.000000  0.740682  0.189985  0.194522  0.490031
# y3 wRC+ -0.044223  0.440045  0.740682  1.000000  0.282596  0.309344  0.742944
# y1 WAR  -0.115026  0.224922  0.189985  0.282596  1.000000  0.458288  0.367587
# y2 WAR  -0.128201  0.211320  0.194522  0.309344  0.458288  1.000000  0.450504
# y3 WAR  -0.150516  0.294317  0.490031  0.742944  0.367587  0.450504  1.000000
# y4 WAR  -0.098169  0.172043  0.263316  0.360871  0.353314  0.415763  0.503920
#
#            y4 WAR
# y3 K%   -0.098169
# y3 BB%   0.172043
# y3 ISO   0.263316
# y3 wRC+  0.360871
# y1 WAR   0.353314
# y2 WAR   0.415763
# y3 WAR   0.503920
# y4 WAR   1.000000

# %%
corr_matrix['y4 WAR'].sort_values(ascending=False)
# Out:
# y4 WAR     1.000000
# y3 WAR     0.503920
# y2 WAR     0.415763
# y3 wRC+    0.360871
# y1 WAR     0.353314
# y3 ISO     0.263316
# y3 BB%     0.172043
# y3 K%     -0.098169
# Name: y4 WAR, dtype: float64

# %% [markdown]
# # <font color='blue'>Part 4: Prepare the data for Machine Learning Algorithms </font>

# %%
# drop labels for training set and then make a copy so as not to affect original
# This doesn't look like the first row of the excel since this is our randomized training set...
predictors = train_set_copy.iloc[:,1:61]
# print(predictors)
labels = train_set_copy.iloc[:,61:].copy()

# baseball = train_set.drop(labels, axis=1)
# Labels
# baseball_labels = train_set[labels].copy()

# %%
print(predictors.shape)
print(predictors)
# Out:
# (1814, 60)
#       y1 Age  y1 G  y1 PA  y1 HR  y1 R  y1 RBI  y1 SB  y1 BB%  y1 K%  y1 ISO  \
# 0         23    81    313      8    37      27      9   0.077  0.268   0.146
# 1         28   123    559      7    82      34     12   0.104  0.204   0.126
# 2         25    45    112      1    13      10      0   0.071  0.125   0.109
# 3         25    53    138      1    15      12      0   0.058  0.101   0.089
# 4         27    47    123      0     9      10      1   0.057  0.195   0.028
# 5         23    98    394      7    40      35      1   0.079  0.175   0.131
# 6         22    72    256      7    31      31      3   0.035  0.230   0.139
# 7         32   134    517     19    38      81      0   0.029  0.103   0.157
# 8         27    93    374      8    40      31     10   0.061  0.166   0.115
# 9         23    76    335      8    41      36      5   0.072  0.155   0.154
# 10        25    46    112      0     9       3      6   0.125  0.232   0.021
# 11        27    52    173      0     9      11      0   0.058  0.283   0.065
# 12        23    34    131      0    17      10      0   0.069  0.198   0.041
# 13        24    64    210      5    18      19      0   0.062  0.248   0.151
# 14        21    62    273      4    34      16     10   0.114  0.242   0.108
# 15        23    50    179      5    18      22      1   0.084  0.240   0.154
# 16        25    37    100      1     8       9      4   0.080  0.280   0.065
# 17        25   134    452     13    46      40      0   0.082  0.175   0.145
# 18        24    69    213      5    32      17      2   0.075  0.192   0.196
# 19        27   132    503      8    65      45     37   0.042  0.129   0.117
# 20        27    64    153      1    26      13     18   0.065  0.176   0.075
# 21        29    46    192      2    31      14      2   0.078  0.109   0.138
# 22        30    47    111      2    12      10      1   0.045  0.279   0.133
# 23        32   117    484      3    58      31     10   0.050  0.045   0.074
# 24        23    57    233      9    32      23      1   0.047  0.240   0.191
# 25        23   103    404      7    47      28      0   0.092  0.161   0.120
# 26        23    95    274      1    37      18     13   0.084  0.088   0.046
# 27        25    43    148      1    16      15     10   0.115  0.243   0.054
# 28        26    37    108      2     8       7      2   0.046  0.157   0.108
# 29        26   105    382     21    44      65      0   0.055  0.212   0.237
# ...      ...   ...    ...    ...   ...     ...    ...     ...    ...     ...
# 0       -1.3     2.4     1.5
# 1        3.7    -3.2     0.9
# 2      -13.5     8.1     0.1
# 3        9.1    -3.0     1.5
# 4       -7.1     8.7     0.9
# 5       -5.2     2.9     0.9
# 6      -14.4   -13.8    -0.9
# 7      -16.2     2.6     0.3
# 8       -7.6    -8.0    -0.6
# 9        3.3   -11.6     0.8
# 10       8.8    -3.9     1.3
# 11      -1.7     2.8     0.8
# 12      -1.2     0.2     1.4
# 13      -4.4    -5.9    -0.2
# 14      14.0    -7.3     2.4
# 15     -10.1   -14.4    -1.1
# 16      -6.4     0.4    -0.1
# 17      -9.8    -9.4    -1.2
# 18       4.3    -6.5     0.5
# 19       0.1    -3.6     0.8
# 20       9.3    13.8     3.5
# 21     -10.3     0.8     0.8
# 22      -3.9    -1.3     0.0
# 23     -10.4    -0.5     0.7
# 24       7.5   -11.0     0.6
# 25      -3.7    14.2     3.1
# 26      -9.8    -0.1    -0.5
# 27      -2.9    -7.0    -0.3
# 28      -9.0     1.8     0.4
# 29      -1.2   -16.0     0.3
# ...      ...     ...     ...
# 1784     4.8    -1.1     1.2
# 1785     2.7    -9.0     0.6
# 1786    -6.3     8.3     2.1
# 1787    11.5    15.4     4.8
# 1788    -3.6     8.1     1.6
# 1789    -9.3    -3.6    -0.2
# 1790     4.1    10.9     3.4
# 1791   -20.3     1.5    -1.0
# 1792   -13.7     1.5     0.2
# 1793    23.6     9.7     5.4
# 1794    25.1    12.1     5.6
# 1795    18.6    13.9     5.4
# 1796     3.4     1.3     1.2
# 1797    21.8    11.9     5.3
# 1798    29.9     6.8     5.2
# 1799    -3.2     9.1     2.4
# 1800    -3.7    19.2     3.3
# 1801   -15.7    21.9     2.3
# 1802     9.1    14.3     4.2
# 1803    20.6    20.2     6.1
# 1804    17.7    17.1     5.5
# 1805    -1.2    14.4     2.9
# 1806   -14.2    10.7     1.4
# 1807    12.0     7.8     3.9
# 1808   -12.1    10.2     1.7
# 1809     8.1     6.1     3.5
# 1810   -19.8    10.8     1.2
# 1811    -3.4    17.5     3.6
# 1812    -7.3   -11.0    -0.1
# 1813     7.2    -6.1     2.1
#
# [1814 rows x 60 columns]

# %%
print(labels.shape)
print(labels)
# Out:
# (1814, 20)
#       y4 Age  y4 G  y4 PA  y4 HR  y4 R  y4 RBI  y4 SB  y4 BB%  y4 K%  y4 ISO  \
# 0         26   123    361      8    32      31      3   0.083  0.188   0.119
# 1         31    64    229      2    21      13      3   0.135  0.179   0.077
# 2         28   102    267      1    18      32      1   0.049  0.139   0.069
# 3         32    90    209      4    26      21      2   0.053  0.196   0.153
# 4         30   109    194      2    21      16      8   0.067  0.196   0.086
# 5         26   156    647     20    91      85     12   0.100  0.181   0.180
# 6         25   120    453     12    59      51      4   0.075  0.254   0.140
# 7         35   118    416      5    27      36      0   0.058  0.082   0.077
# 8         30    70    189      1     9      13      0   0.090  0.201   0.077
# 9         26   152    601     30    73      81      6   0.078  0.248   0.239
# 10        28   102    209      3    25      10     13   0.053  0.340   0.079
# 11        31    33    121      3    10      15      0   0.050  0.331   0.121
# std     523.801012     3.591649    37.076949   182.305890    10.096915
# min       0.000000    19.000000    22.000000   100.000000     0.000000
# 25%     453.250000    25.000000    88.000000   302.250000     5.000000
# 50%     906.500000    27.000000   125.000000   484.000000    11.000000
# 75%    1359.750000    30.000000   149.000000   614.000000    20.000000
# max    1813.000000    42.000000   163.000000   778.000000    54.000000
#
#               y1 R       y1 RBI        y1 SB       y1 BB%        y1 K%  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean     56.800992    54.047409     8.352260     0.086315     0.179969
# std      28.060540    29.679516    10.623266     0.031443     0.057665
# min       4.000000     2.000000     0.000000     0.006000     0.043000
# 25%      33.000000    30.000000     1.000000     0.064000     0.137250
# 50%      56.000000    51.000000     4.000000     0.083000     0.175000
# 75%      79.000000    76.000000    11.000000     0.106000     0.218000
# max     143.000000   156.000000    78.000000     0.207000     0.380000
#
#           ...          y4 BABIP       y4 AVG       y4 OBP       y4 SLG  \
# count     ...       1814.000000  1814.000000  1814.000000  1814.000000
# mean      ...          0.294716     0.255066     0.322724     0.404682
# std       ...          0.038271     0.035141     0.038983     0.076147
# min       ...          0.146000     0.140000     0.193000     0.183000
# 25%       ...          0.270000     0.233000     0.298000     0.351250
# 50%       ...          0.297000     0.256000     0.323000     0.402000
# 75%       ...          0.320000     0.280000     0.347000     0.454000
# max       ...          0.408000     0.359000     0.474000     0.649000
#
#            y4 WOBA      y4 wRC+       y4 BsR       y4 Off       y4 Def  \
# count  1814.000000  1814.000000  1814.000000  1814.000000  1814.000000
# mean      0.317909    98.560639    -0.274807     2.212073    -1.271499
# std       0.042510    28.566571     3.288815    14.724312     8.735438
# min       0.180000     6.000000   -12.700000   -32.800000   -32.300000
# 25%       0.290000    80.000000    -2.100000    -7.800000    -6.900000
# 50%       0.318500    99.000000    -0.300000    -0.700000    -1.300000
# 75%       0.345000   117.000000     1.400000     9.400000     4.000000
# max       0.461000   197.000000    13.600000    77.300000    28.000000
#
#             y4 WAR
# count  1814.000000
# mean      1.564168
# std       2.009985
# min      -2.900000
# 25%       0.000000
# 50%       1.100000
# 75%       2.700000
# max       9.500000
#
# [8 rows x 81 columns]

# %% [markdown]
# No missing values and no categorical variables to convert to numerical, so we can proceed

# %% [markdown]
# ### 4.4: Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
print(predictors)
# Out:
#       y1 Age  y1 G  y1 PA  y1 HR  y1 R  y1 RBI  y1 SB  y1 BB%  y1 K%  y1 ISO  \
# 0         23    81    313      8    37      27      9   0.077  0.268   0.146
# 1         28   123    559      7    82      34     12   0.104  0.204   0.126
# 2         25    45    112      1    13      10      0   0.071  0.125   0.109
# 3         25    53    138      1    15      12      0   0.058  0.101   0.089
# 4         27    47    123      0     9      10      1   0.057  0.195   0.028
# 5         23    98    394      7    40      35      1   0.079  0.175   0.131
# 6         22    72    256      7    31      31      3   0.035  0.230   0.139
# 7         32   134    517     19    38      81      0   0.029  0.103   0.157
# 8         27    93    374      8    40      31     10   0.061  0.166   0.115
# 9         23    76    335      8    41      36      5   0.072  0.155   0.154
# 10        25    46    112      0     9       3      6   0.125  0.232   0.021
# 1808   -12.1    10.2     1.7
# 1809     8.1     6.1     3.5
# 1810   -19.8    10.8     1.2
# 1811    -3.4    17.5     3.6
# 1812    -7.3   -11.0    -0.1
# 1813     7.2    -6.1     2.1
#
# [1814 rows x 60 columns]

# %%
# Initialize
scaler = StandardScaler()

def standardize(data):
    baseball_standardized = scaler.fit_transform(data)
    return baseball_standardized

# %%
predictors_standardized = (standardize(predictors))
# print(predictors_standardized)
print(predictors)
# Out:
#       y1 Age  y1 G  y1 PA  y1 HR  y1 R  y1 RBI  y1 SB  y1 BB%  y1 K%  y1 ISO  \
# 0         23    81    313      8    37      27      9   0.077  0.268   0.146
# 1         28   123    559      7    82      34     12   0.104  0.204   0.126
# 2         25    45    112      1    13      10      0   0.071  0.125   0.109
# 3         25    53    138      1    15      12      0   0.058  0.101   0.089
# 4         27    47    123      0     9      10      1   0.057  0.195   0.028
# 5         23    98    394      7    40      35      1   0.079  0.175   0.131
# 6         22    72    256      7    31      31      3   0.035  0.230   0.139
# 7         32   134    517     19    38      81      0   0.029  0.103   0.157
# 8         27    93    374      8    40      31     10   0.061  0.166   0.115
# 9         23    76    335      8    41      36      5   0.072  0.155   0.154
# 10        25    46    112      0     9       3      6   0.125  0.232   0.021
# 11        27    52    173      0     9      11      0   0.058  0.283   0.065
# 12        23    34    131      0    17      10      0   0.069  0.198   0.041
# 13        24    64    210      5    18      19      0   0.062  0.248   0.151
# 14        21    62    273      4    34      16     10   0.114  0.242   0.108
# 15        23    50    179      5    18      22      1   0.084  0.240   0.154
# 16        25    37    100      1     8       9      4   0.080  0.280   0.065
# 17        25   134    452     13    46      40      0   0.082  0.175   0.145
# 18        24    69    213      5    32      17      2   0.075  0.192   0.196
# 19        27   132    503      8    65      45     37   0.042  0.129   0.117
# 20        27    64    153      1    26      13     18   0.065  0.176   0.075
# 21        29    46    192      2    31      14      2   0.078  0.109   0.138
# 22        30    47    111      2    12      10      1   0.045  0.279   0.133
# 23        32   117    484      3    58      31     10   0.050  0.045   0.074
# 24        23    57    233      9    32      23      1   0.047  0.240   0.191
# 25        23   103    404      7    47      28      0   0.092  0.161   0.120
# 26        23    95    274      1    37      18     13   0.084  0.088   0.046
# 27        25    43    148      1    16      15     10   0.115  0.243   0.054
# 28        26    37    108      2     8       7      2   0.046  0.157   0.108
# 29        26   105    382     21    44      65      0   0.055  0.212   0.237
# ...      ...   ...    ...    ...   ...     ...    ...     ...    ...     ...
# 1784      27   145    641     25    93      95      5   0.089  0.181   0.196
# 1785      28   147    633     26    84      79      6   0.095  0.210   0.190
# 1786      24   150    619     12    60      60      9   0.097  0.162   0.133
# 1787      25   152    663     21    91      67      3   0.062  0.164   0.211
# 1788      26   135    595     12    71      65      5   0.082  0.146   0.167
# 1789      27   151    633     15    83      61     10   0.098  0.171   0.181
# 1790      28    86    354      5    44      45      4   0.085  0.209   0.143
# 1791      29    79    327      7    38      28      1   0.113  0.232   0.125
# 1792      30   124    501     13    57      67      6   0.108  0.248   0.190
# 1793      22   155    682     24   104      99      7   0.084  0.191   0.189
# 19       0.1    -3.6     0.8
# 20       9.3    13.8     3.5
# 21     -10.3     0.8     0.8
# 22      -3.9    -1.3     0.0
# 23     -10.4    -0.5     0.7
# 24       7.5   -11.0     0.6
# 25      -3.7    14.2     3.1
# 26      -9.8    -0.1    -0.5
# 27      -2.9    -7.0    -0.3
# 28      -9.0     1.8     0.4
# 29      -1.2   -16.0     0.3
# ...      ...     ...     ...
# 1784     4.8    -1.1     1.2
# 1785     2.7    -9.0     0.6
# 1786    -6.3     8.3     2.1
# 1787    11.5    15.4     4.8
# 1788    -3.6     8.1     1.6
# 1789    -9.3    -3.6    -0.2
# 1790     4.1    10.9     3.4
# 1791   -20.3     1.5    -1.0
# 1792   -13.7     1.5     0.2
# 1793    23.6     9.7     5.4
# 1794    25.1    12.1     5.6
# 1795    18.6    13.9     5.4
# 1796     3.4     1.3     1.2
# 1797    21.8    11.9     5.3
# 1798    29.9     6.8     5.2
# 1799    -3.2     9.1     2.4
# 1800    -3.7    19.2     3.3
# 1801   -15.7    21.9     2.3
# 1802     9.1    14.3     4.2
# 1803    20.6    20.2     6.1
# 1804    17.7    17.1     5.5
# 1805    -1.2    14.4     2.9
# 1806   -14.2    10.7     1.4
# 1807    12.0     7.8     3.9
# 1808   -12.1    10.2     1.7
# 1809     8.1     6.1     3.5
# 1810   -19.8    10.8     1.2
# 1811    -3.4    17.5     3.6
# 1812    -7.3   -11.0    -0.1
# 1813     7.2    -6.1     2.1
#
# [1814 rows x 60 columns]

# %% [markdown]
# # <font color='blue'>Part 5: Select and Train a Model </font>

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(predictors, labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Let's try the full pipeline on a few training instances, say the first 5
some_data = baseball.iloc[:5]
some_labels = baseball_labels.iloc[:5]
# Since we have previously defined pipelines, the program recalls the following:
some_data_prepared = standardize(some_data)

print("Predictions:", lin_reg.predict(some_data_prepared))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-e8f342d8516f> in <module>()
#       1 # Let's try the full pipeline on a few training instances, say the first 5
#       2 some_data = baseball.iloc[:5]
# ----> 3 some_labels = baseball_labels.iloc[:5]
#       4 # Since we have previously defined pipelines, the program recalls the following:
#       5 some_data_prepared = standardize(some_data)
#
# NameError: name 'baseball_labels' is not defined

# %%
from sklearn.metrics import mean_squared_error

print(test_dataset.shape)
baseball_predictions = lin_reg.predict(test_dataset)
# Our error function which takes in two arguments, the labels and the predictions
#lin_mse = mean_squared_error(war_labels, baseball_predictions)
# Take the square root to rescale absolute differences
#lin_rmse = np.sqrt(lin_mse)
#print(lin_rmse)
print(baseball_predictions.shape)
# Out:
# (278, 60)
# (278, 20)

# %%
output = pd.DataFrame(baseball_predictions)
output.to_csv("datasets/baseball/outputs/output1.csv")

# %% [markdown]
# ### Let's try a different algorithm: Decision Trees

# %% [markdown]
# ### Let's try a different algorithm: Decision Trees

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(baseball_standardized, war_labels)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
baseball_predictions = tree_reg.predict(baseball_standardized)
tree_mse = mean_squared_error(war_labels, baseball_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 2.2367642033395347e-17

# %% [markdown]
# Definitely an overfit here...
